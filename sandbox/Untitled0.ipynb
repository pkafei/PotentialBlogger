# %%
from bs4 import BeautifulSoup
import requests

# %%
url = raw_input("Enter a URL:")

r = requests.get("http://" +url)

data = r.text

soup = BeautifulSoup(data)

for link in soup.find_all('a'):
    print(link.get('href'   ))
# Out:
# Enter a URL:http://www.socialpsychology.org/blogs.htm
# ---------------------------------------------------------------------------
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-2-0734804c6811> in <module>()
#       1 url = raw_input("Enter a URL:")
#       2
# ----> 3 r = requests.get("http://" +url)
#       4
#       5 data = r.text
#
# /Users/portiaburton/anaconda/lib/python2.7/site-packages/requests/api.pyc in get(url, **kwargs)
#      53
#      54     kwargs.setdefault('allow_redirects', True)
# ---> 55     return request('get', url, **kwargs)
#      56
#      57
#
# /Users/portiaburton/anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      42
#      43     session = sessions.Session()
# ---> 44     return session.request(method=method, url=url, **kwargs)
#      45
#      46
#
# /Users/portiaburton/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert)
#     446         }
#     447         send_kwargs.update(settings)
# --> 448         resp = self.send(prep, **send_kwargs)
#     449
#     450         return resp
#
# /Users/portiaburton/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     552
#     553         # Send the request
# --> 554         r = adapter.send(request, **kwargs)
#     555
#     556         # Total elapsed time of the request (approximately)
#
# /Users/portiaburton/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     357                     decode_content=False,
#     358                     retries=Retry(self.max_retries, read=False),
# --> 359                     timeout=timeout
#     360                 )
#     361
#
# /Users/portiaburton/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     557
#     558             retries = retries.increment(method, url, error=e,
# --> 559                                         _pool=self, _stacktrace=stacktrace)
#     560             retries.sleep()
#     561
#
# /Users/portiaburton/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/retry.pyc in increment(self, method, url, response, error, _pool, _stacktrace)
#     243             # Read retry?
#     244             if read is False:
# --> 245                 raise six.reraise(type(error), error, _stacktrace)
#     246             elif read is not None:
#     247                 read -= 1
#
# /Users/portiaburton/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     514             httplib_response = self._make_request(conn, method, url,
#     515                                                   timeout=timeout,
# --> 516                                                   body=body, headers=headers)
#     517
#     518             # If we're going to release the connection in ``finally:``, then
#
# /Users/portiaburton/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     306         # conn.request() calls httplib.*.request, not the method in
#     307         # urllib3.request. It also calls makefile (recv) on the socket.
# --> 308         conn.request(method, url, **httplib_request_kw)
#     309
#     310         # Reset the timeout for the recv() on the socket
#
# /Users/portiaburton/anaconda/python.app/Contents/lib/python2.7/httplib.pyc in request(self, method, url, body, headers)
#     993     def request(self, method, url, body=None, headers={}):
#     994         """Send a complete request to the server."""
# --> 995         self._send_request(method, url, body, headers)
#     996
#     997     def _set_content_length(self, body):
#
# /Users/portiaburton/anaconda/python.app/Contents/lib/python2.7/httplib.pyc in _send_request(self, method, url, body, headers)
#    1027         for hdr, value in headers.iteritems():
#    1028             self.putheader(hdr, value)
# -> 1029         self.endheaders(body)
#    1030
#    1031     def getresponse(self, buffering=False):
#
# /Users/portiaburton/anaconda/python.app/Contents/lib/python2.7/httplib.pyc in endheaders(self, message_body)
#     989         else:
#     990             raise CannotSendHeader()
# --> 991         self._send_output(message_body)
#     992
#     993     def request(self, method, url, body=None, headers={}):
#
# /Users/portiaburton/anaconda/python.app/Contents/lib/python2.7/httplib.pyc in _send_output(self, message_body)
#     842             msg += message_body
#     843             message_body = None
# --> 844         self.send(msg)
#     845         if message_body is not None:
#     846             #message_body was not a string (i.e. it is a file) and
#
# /Users/portiaburton/anaconda/python.app/Contents/lib/python2.7/httplib.pyc in send(self, data)
#     804         if self.sock is None:
#     805             if self.auto_open:
# --> 806                 self.connect()
#     807             else:
#     808                 raise NotConnected()
#
# /Users/portiaburton/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connection.pyc in connect(self)
#     144
#     145     def connect(self):
# --> 146         conn = self._new_conn()
#     147         self._prepare_conn(conn)
#     148
#
# /Users/portiaburton/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connection.pyc in _new_conn(self)
#     123         try:
#     124             conn = connection.create_connection(
# --> 125                 (self.host, self.port), self.timeout, **extra_kw)
#     126
#     127         except SocketTimeout:
#
# /Users/portiaburton/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/connection.pyc in create_connection(address, timeout, source_address, socket_options)
#      62     host, port = address
#      63     err = None
# ---> 64     for res in socket.getaddrinfo(host, port, 0, socket.SOCK_STREAM):
#      65         af, socktype, proto, canonname, sa = res
#      66         sock = None
#
# ProtocolError: ('Connection aborted.', gaierror(8, 'nodename nor servname provided, or not known'))
